# %%
import matplotlib.pyplot as plt

# %%
train_loss = [7.0060, 5.8172, 5.1957, 4.7550, 4.4015, 4.1071, 3.8554, 3.6538, 3.4939, 3.3691,
              3.2644, 3.1828, 3.1156, 3.0467, 2.9721, 2.9067, 2.8490, 2.7987, 2.7527, 2.7131,
              2.6746, 2.6402, 2.6093, 2.5800, 2.5527]

valid_loss = [6.2116, 5.4643, 4.9968, 4.6435, 4.3736, 4.1492, 3.9800, 3.8544, 3.7319, 3.6762,
              3.6248, 3.5923, 3.5487, 3.5052, 3.4875, 3.4629, 3.4460, 3.4475, 3.4340, 3.4329,
              3.4445, 3.4277, 3.4349, 3.4450, 3.4537]

# %%
epoch = range(1, 26)
plt.figure(figsize=(10, 6))
plt.plot(epoch, train_loss, 'ro-', label='Train loss')
plt.plot(epoch, valid_loss, 'bo-', label='Valid loss')
#plt.xticks(ticks=epoch)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='best')
plt.show()
